# %% [markdown]
# # DATA LOADING

# %%
# importing the libraries required

import numpy as np
import pandas as pd

# %%
# reading the dataset

df = pd.read_csv("trees_dataset.csv")

# %%
# printing the data set

df
# Out:
#      OBJECTID  Tree ID  Tree Type        Genus    Species  \
# 0           1    10146  DECIDUOUS      Quercus    bicolor
# 1           2    10150  DECIDUOUS  Gymnocladus    dioicus
# 2           3    10041  DECIDUOUS      Quercus      rubra
# 3           4    10042  DECIDUOUS      Quercus      rubra
# 4           5    10051  DECIDUOUS    Crataegus        NaN
# ..        ...      ...        ...          ...        ...
# 772       773    13830  DECIDUOUS     Taxodium        NaN
# 773       774    13833  DECIDUOUS    Crataegus        NaN
# 774       775    14027  DECIDUOUS      Catalpa   speciosa
# 775       776    15693  DECIDUOUS         Acer  saccharum
# 776       777    15694  DECIDUOUS         Acer  saccharum
#
#     Cultivar or Varietal          Common Name  Canopy Spread  Height  \
# 0                    NaN      Swamp White Oak           19.0    21.0
# 1                    NaN  Kentucky Coffeetree           31.0    47.0
# 2                    NaN     Northern Red Oak           65.0   102.0
# 3                    NaN     Northern Red Oak           42.0    54.0
# 4                    NaN            Hawthorne           18.0    20.0
# ..                   ...                  ...            ...     ...
# 772                  NaN         Bald Cypress           15.0    25.0
# 773                  NaN            Hawthorne           15.0    20.0
# 774                  NaN      Western Catalpa            5.0    10.0
# 775                Caddo                  NaN            NaN     NaN
# 776                Caddo          Sugar Maple            NaN    12.0
#
#       Latitude   Longitude
# 0    40.009104 -105.272529
# 1    40.009136 -105.272797
# 2    40.008888 -105.274886
# 3    40.008775 -105.275000
# 4    40.008870 -105.275428
# ..         ...         ...
# 772  40.010252 -105.273964
# 773  40.010316 -105.274258
# 774  40.008315 -105.272798
# 775  40.009700 -105.274889
# 776  40.009862 -105.275143
#
# [777 rows x 11 columns]

# %% [markdown]
# # DATA CLEANING

# %%
# Checking for null values in all columns

df.isnull().sum()
# Out:
# OBJECTID                  0
# Tree ID                   0
# Tree Type                 0
# Genus                     0
# Species                 196
# Cultivar or Varietal    770
# Common Name               1
# Canopy Spread             4
# Height                    1
# Latitude                  0
# Longitude                 0
# dtype: int64

# %%
# Replacing missing species with unknown.

df['Species'] = df['Species'].fillna('Unknown')

# %%
df
# Out:
#      OBJECTID  Tree ID  Tree Type        Genus    Species  \
# 0           1    10146  DECIDUOUS      Quercus    bicolor
# 1           2    10150  DECIDUOUS  Gymnocladus    dioicus
# 2           3    10041  DECIDUOUS      Quercus      rubra
# 3           4    10042  DECIDUOUS      Quercus      rubra
# 4           5    10051  DECIDUOUS    Crataegus    Unknown
# ..        ...      ...        ...          ...        ...
# 772       773    13830  DECIDUOUS     Taxodium    Unknown
# 773       774    13833  DECIDUOUS    Crataegus    Unknown
# 774       775    14027  DECIDUOUS      Catalpa   speciosa
# 775       776    15693  DECIDUOUS         Acer  saccharum
# 776       777    15694  DECIDUOUS         Acer  saccharum
#
#     Cultivar or Varietal          Common Name  Canopy Spread  Height  \
# 0                    NaN      Swamp White Oak           19.0    21.0
# 1                    NaN  Kentucky Coffeetree           31.0    47.0
# 2                    NaN     Northern Red Oak           65.0   102.0
# 3                    NaN     Northern Red Oak           42.0    54.0
# 4                    NaN            Hawthorne           18.0    20.0
# ..                   ...                  ...            ...     ...
# 772                  NaN         Bald Cypress           15.0    25.0
# 773                  NaN            Hawthorne           15.0    20.0
# 774                  NaN      Western Catalpa            5.0    10.0
# 775                Caddo                  NaN            NaN     NaN
# 776                Caddo          Sugar Maple            NaN    12.0
#
#       Latitude   Longitude
# 0    40.009104 -105.272529
# 1    40.009136 -105.272797
# 2    40.008888 -105.274886
# 3    40.008775 -105.275000
# 4    40.008870 -105.275428
# ..         ...         ...
# 772  40.010252 -105.273964
# 773  40.010316 -105.274258
# 774  40.008315 -105.272798
# 775  40.009700 -105.274889
# 776  40.009862 -105.275143
#
# [777 rows x 11 columns]

# %%
# checking again

df.isnull().sum()
# Out:
# OBJECTID                  0
# Tree ID                   0
# Tree Type                 0
# Genus                     0
# Species                   0
# Cultivar or Varietal    770
# Common Name               1
# Canopy Spread             4
# Height                    1
# Latitude                  0
# Longitude                 0
# dtype: int64

# %%
# Dropping the column "Cultivar or Varietal" since ih has more than 97% of missing values.

df = df.drop('Cultivar or Varietal', axis = 1)

# %%
# checking again

df.isnull().sum()
# Out:
# OBJECTID         0
# Tree ID          0
# Tree Type        0
# Genus            0
# Species          0
# Common Name      1
# Canopy Spread    4
# Height           1
# Latitude         0
# Longitude        0
# dtype: int64

# %%
# Checking the missing values of canopy spread

df[df['Tree Type'] == 'DECIDUOUS']['Canopy Spread'].to_frame().isnull().sum()
# Out:
# Canopy Spread    4
# dtype: int64

# %%
# Checking statistics of Canopy Spread to decide which one to use between mean and median

df['Canopy Spread'].describe()
# Out:
# count    773.000000
# mean      19.345408
# std       10.950121
# min        3.000000
# 25%       12.000000
# 50%       16.000000
# 75%       25.000000
# max       65.000000
# Name: Canopy Spread, dtype: float64

# %%
# calculating median for canopy spread since the mean and 50% values are not equal and there are certain outliers

canopy_median = df[df['Tree Type'] == 'DECIDUOUS']['Canopy Spread'].median()

# %%
# replacing canopy spread with median since mean is prone to outliers (It can be seen from describe() the column stats)

df['Canopy Spread'] = df['Canopy Spread'].fillna(canopy_median)

# %%
# Now handling the missing values in height column

df[df['Height'].isnull()]
# Out:
#      OBJECTID  Tree ID  Tree Type Genus    Species Common Name  Canopy Spread  \
# 775       776    15693  DECIDUOUS  Acer  saccharum         NaN           18.0
#
#      Height  Latitude   Longitude
# 775     NaN   40.0097 -105.274889

# %%
# Checking statistics of Height to decide which one to use between mean and median

df['Height'].describe()
# Out:
# count    776.000000
# mean      34.748711
# std       18.928729
# min        0.000000
# 25%       20.000000
# 50%       35.000000
# 75%       47.000000
# max      102.000000
# Name: Height, dtype: float64

# %%
# We can use mean here as there are no outliers. 

# But since there are different spicies of trees with various genes we can either 
# calculate mean value for that particular category or replace with median value of that particular category.

# Since the missing value is from DECIDUOUS category replacing with median height of that particular category

deciduos_median_height = df[df['Tree Type'] == 'DECIDUOUS']['Height'].median()

# %%
deciduos_median_height
# Out:
# 30.0

# %%
# Replacing value

df['Height'].fillna(deciduos_median_height, inplace = True)

# %%
# Handling missing value for common name

df['Common Name'].fillna('Unknown',inplace = True)

# %%
# Finally all missing values are imputed and there are no missing values.

df.isnull().sum()
# Out:
# OBJECTID         0
# Tree ID          0
# Tree Type        0
# Genus            0
# Species          0
# Common Name      0
# Canopy Spread    0
# Height           0
# Latitude         0
# Longitude        0
# dtype: int64

# %%
# Final Cleaned Data Frame

df
# Out:
#      OBJECTID  Tree ID  Tree Type        Genus    Species  \
# 0           1    10146  DECIDUOUS      Quercus    bicolor
# 1           2    10150  DECIDUOUS  Gymnocladus    dioicus
# 2           3    10041  DECIDUOUS      Quercus      rubra
# 3           4    10042  DECIDUOUS      Quercus      rubra
# 4           5    10051  DECIDUOUS    Crataegus    Unknown
# ..        ...      ...        ...          ...        ...
# 772       773    13830  DECIDUOUS     Taxodium    Unknown
# 773       774    13833  DECIDUOUS    Crataegus    Unknown
# 774       775    14027  DECIDUOUS      Catalpa   speciosa
# 775       776    15693  DECIDUOUS         Acer  saccharum
# 776       777    15694  DECIDUOUS         Acer  saccharum
#
#              Common Name  Canopy Spread  Height   Latitude   Longitude
# 0        Swamp White Oak           19.0    21.0  40.009104 -105.272529
# 1    Kentucky Coffeetree           31.0    47.0  40.009136 -105.272797
# 2       Northern Red Oak           65.0   102.0  40.008888 -105.274886
# 3       Northern Red Oak           42.0    54.0  40.008775 -105.275000
# 4              Hawthorne           18.0    20.0  40.008870 -105.275428
# ..                   ...            ...     ...        ...         ...
# 772         Bald Cypress           15.0    25.0  40.010252 -105.273964
# 773            Hawthorne           15.0    20.0  40.010316 -105.274258
# 774      Western Catalpa            5.0    10.0  40.008315 -105.272798
# 775              Unknown           18.0    30.0  40.009700 -105.274889
# 776          Sugar Maple           18.0    12.0  40.009862 -105.275143
#
# [777 rows x 10 columns]

# %% [markdown]
# # DATA STATS AND OUTLIER DETECTION

# %%
# checking stats for 'Height column'

df['Height'].describe()
# Out:
# count    777.000000
# mean      34.742600
# std       18.917296
# min        0.000000
# 25%       20.000000
# 50%       35.000000
# 75%       47.000000
# max      102.000000
# Name: Height, dtype: float64

# %% [markdown]
# The height of a tree can't be zero. We have to deal with the rows which have **height = 0** as their value.

# %%
# importing matplotlib

import matplotlib.pyplot as plt

# %%
# Visualising 'height'

df['Height'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ### HANDLING ROWS WITH HEIGHT = 0

# %%
# checking for rows with height as 0

df[df['Height'] == 0]
# Out:
#      OBJECTID  Tree ID  Tree Type      Genus       Species        Common Name  \
# 92         93    13798  DECIDUOUS   Fraxinus       Unknown                Ash
# 174       175    13799  DECIDUOUS   Fraxinus       Unknown                Ash
# 175       176    13808  DECIDUOUS   Fraxinus       Unknown                Ash
# 213       214    14138  DECIDUOUS  Hydrangea    paniculata  Panicle hydrangea
# 265       266    13811  DECIDUOUS   Fraxinus       Unknown                Ash
# 476       477    13797  DECIDUOUS      Pinus       Unknown               Pine
# 477       478    13801  DECIDUOUS  Crataegus        mollis     Downy Hawthorn
# 478       479    13804  DECIDUOUS      Malus       Unknown              Apple
# 479       480    13805  DECIDUOUS   Fraxinus       Unknown                Ash
# 480       481    13807  DECIDUOUS  Crataegus        mollis     Downy Hawthorn
# 678       679    13800  DECIDUOUS   Fraxinus       Unknown                Ash
# 679       680    13802  DECIDUOUS  Crataegus        mollis     Downy Hawthorn
# 767       768    13803  DECIDUOUS     Celtis  occidentalis   Common Hackberry
# 768       769    13812  DECIDUOUS    Rhamnus       Unknown          Buckthorn
#
#      Canopy Spread  Height   Latitude   Longitude
# 92            12.0     0.0  40.010068 -105.273288
# 174           12.0     0.0  40.010080 -105.273284
# 175           12.0     0.0  40.009974 -105.273221
# 213            6.0     0.0  40.010040 -105.275953
# 265           12.0     0.0  40.009915 -105.273204
# 476           12.0     0.0  40.009890 -105.273232
# 477           12.0     0.0  40.010097 -105.273258
# 478           12.0     0.0  40.010040 -105.273185
# 479           12.0     0.0  40.010041 -105.273281
# 480           12.0     0.0  40.010001 -105.273260
# 678           12.0     0.0  40.010089 -105.273293
# 679           12.0     0.0  40.010058 -105.273240
# 767           12.0     0.0  40.010022 -105.273259
# 768           12.0     0.0  40.009924 -105.273231

# %% [markdown]
# # STEPS TO CONSIDER
#
# **1.** There are 14 trees with height as 0.
#
# **2.** These 14 trees belong to different **Genus** which again might have different median heights.
#
# **3.** So, it is important to check for category specific heights.
#
# **4.** Looking at the data frame we can see that there are **2 major categories** with missing heights
#
# **5.** So, Let's first deal with **Fraxinus and Crataegus** genes

# %%
# Calculating median height for Fraxinus

fraxinus_median = df[df['Genus'] == 'Fraxinus']['Height'].median()

# %%
fraxinus_median
# Out:
# 35.0

# %%
# Calculating median height for Crataegus (Downy Hawthorn)

crataegus_median = df[(df['Genus'] == 'Crataegus') & (df['Common Name'] == "Downy Hawthorn")]['Height'].median()

# %%
# Now inspecting the Pinus Genus

df[df['Genus'] == 'Pinus']
# Out:
#      OBJECTID  Tree ID   Tree Type  Genus       Species  \
# 17         18    10467  CONIFEROUS  Pinus         nigra
# 18         19    10468  CONIFEROUS  Pinus          mugo
# 19         20    10472  CONIFEROUS  Pinus     ponderosa
# 20         21    10479  CONIFEROUS  Pinus     ponderosa
# 21         22    10480  CONIFEROUS  Pinus     ponderosa
# 39         40    12424  CONIFEROUS  Pinus     ponderosa
# 40         41    12425  CONIFEROUS  Pinus     ponderosa
# 62         63    12824  CONIFEROUS  Pinus     ponderosa
# 101       102    10112  CONIFEROUS  Pinus       strobus
# 102       103    10113  CONIFEROUS  Pinus     ponderosa
# 116       117    10471  CONIFEROUS  Pinus         nigra
# 128       129    11211  CONIFEROUS  Pinus         nigra
# 133       134    12332  CONIFEROUS  Pinus     ponderosa
# 153       154    12725  CONIFEROUS  Pinus     ponderosa
# 185       186    10065  CONIFEROUS  Pinus     ponderosa
# 186       187    10114  CONIFEROUS  Pinus     monticola
# 190       191    10316  CONIFEROUS  Pinus         nigra
# 191       192    10318  CONIFEROUS  Pinus         nigra
# 200       201    10475  CONIFEROUS  Pinus     ponderosa
# 201       202    10477  CONIFEROUS  Pinus     ponderosa
# 217       218    12337  CONIFEROUS  Pinus      flexilis
# 229       230    12906  CONIFEROUS  Pinus     ponderosa
# 262       263    13476  CONIFEROUS  Pinus          mugo
# 285       286    10469  CONIFEROUS  Pinus     ponderosa
# 309       310    12423  CONIFEROUS  Pinus      flexilis
# 315       316    12622  CONIFEROUS  Pinus     ponderosa
# 327       328    12726  CONIFEROUS  Pinus     ponderosa
# 380       381    10115  CONIFEROUS  Pinus     ponderosa
# 389       390    10317  CONIFEROUS  Pinus         nigra
# 397       398    10476  CONIFEROUS  Pinus     ponderosa
# 398       399    10478  CONIFEROUS  Pinus     ponderosa
# 414       415    12426  CONIFEROUS  Pinus     ponderosa
# 439       440    12849  CONIFEROUS  Pinus       strobus
# 440       441    12853  CONIFEROUS  Pinus        edulis
# 442       443    12857  CONIFEROUS  Pinus     ponderosa
# 448       449    12958  CONIFEROUS  Pinus     ponderosa
# 476       477    13797   DECIDUOUS  Pinus       Unknown
# 522       523    12338  CONIFEROUS  Pinus      flexilis
# 536       537    12907  CONIFEROUS  Pinus     ponderosa
# 671       672    13035  CONIFEROUS  Pinus          mugo
# 673       674    13475  CONIFEROUS  Pinus          mugo
# 690       691    10244  CONIFEROUS  Pinus  strobiformis
# 698       699    10470  CONIFEROUS  Pinus         nigra
# 720       721    12331  CONIFEROUS  Pinus     ponderosa
# 727       728    12621  CONIFEROUS  Pinus          mugo
# 746       747    12961  CONIFEROUS  Pinus     ponderosa
#
#                  Common Name  Canopy Spread  Height   Latitude   Longitude
# 17             Austrian Pine           16.0    29.0  40.010325 -105.276060
# 18                 Mugo Pine            7.0     5.0  40.010229 -105.276061
# 19            Ponderosa Pine           16.0    30.0  40.010311 -105.275955
# 20            Ponderosa Pine           15.0    60.0  40.010306 -105.275760
# 21            Ponderosa Pine           15.0    50.0  40.010324 -105.275713
# 39            Ponderosa Pine           32.0    60.0  40.009870 -105.272273
# 40            Ponderosa Pine           25.0    50.0  40.009923 -105.272288
# 62            Ponderosa Pine           25.0    54.0  40.008299 -105.271346
# 101       Eastern White Pine           32.0    55.0  40.009335 -105.272590
# 102           Ponderosa Pine           15.0    37.0  40.009309 -105.272991
# 116            Austrian Pine           16.0    30.0  40.010308 -105.275860
# 128            Austrian Pine           17.0    45.0  40.008326 -105.272240
# 133           Ponderosa Pine           25.0    50.0  40.009948 -105.272380
# 153           Ponderosa Pine           30.0    50.0  40.008104 -105.274468
# 185           Ponderosa Pine           32.0    69.0  40.009097 -105.275195
# 186       Western White Pine           33.0    57.0  40.009273 -105.273023
# 190            Austrian Pine           25.0    39.0  40.009513 -105.274608
# 191            Austrian Pine           25.0    54.0  40.009667 -105.274586
# 200           Ponderosa Pine           15.0    66.0  40.010314 -105.275823
# 201           Ponderosa Pine           15.0    60.0  40.010281 -105.275796
# 217              Limber Pine           20.0    63.0  40.010322 -105.272120
# 229           Ponderosa Pine           30.0    47.0  40.009304 -105.275719
# 262                Mugo Pine           20.0    51.0  40.008313 -105.274711
# 285           Ponderosa Pine           20.0    62.0  40.010250 -105.275671
# 309              Limber Pine           16.0    35.0  40.009536 -105.272054
# 315           Ponderosa Pine           25.0    53.0  40.008164 -105.275006
# 327           Ponderosa Pine           30.0    56.0  40.008116 -105.274564
# 380           Ponderosa Pine           19.0    55.0  40.009321 -105.273057
# 389            Austrian Pine           25.0    50.0  40.009545 -105.274595
# 397           Ponderosa Pine           15.0    60.0  40.010245 -105.275780
# 398           Ponderosa Pine           15.0    60.0  40.010272 -105.275752
# 414           Ponderosa Pine           25.0    50.0  40.009962 -105.272318
# 439       Eastern White Pine           35.0    45.0  40.007772 -105.273028
# 440     Colorado Pinyon Pine            6.0    10.0  40.009291 -105.271282
# 442           Ponderosa Pine           25.0    49.0  40.009289 -105.271058
# 448           Ponderosa Pine           16.0    45.0  40.007090 -105.272566
# 476                     Pine           12.0     0.0  40.009890 -105.273232
# 522              Limber Pine           25.0    67.0  40.010331 -105.272193
# 536           Ponderosa Pine           12.0    20.0  40.009273 -105.275715
# 671                Mugo Pine           20.0    20.0  40.010038 -105.274444
# 673                Mugo Pine           20.0    51.0  40.008572 -105.274977
# 690  Southwestern White Pine           32.0    52.0  40.009523 -105.275255
# 698            Austrian Pine           16.0    38.0  40.010272 -105.275818
# 720           Ponderosa Pine           25.0    50.0  40.010007 -105.272468
# 727                Mugo Pine            6.0     8.0  40.008493 -105.275106
# 746           Ponderosa Pine            6.0    20.0  40.007094 -105.272641

# %%
# Inspecting Fraxinus

df[df['Genus'] == 'Fraxinus']
# Out:
#      OBJECTID  Tree ID  Tree Type     Genus        Species Common Name  \
# 22         23    10750  DECIDUOUS  Fraxinus      americana   White Ash
# 23         24    10762  DECIDUOUS  Fraxinus  pennsylvanica   Green Ash
# 24         25    10763  DECIDUOUS  Fraxinus  pennsylvanica   Green Ash
# 25         26    10771  DECIDUOUS  Fraxinus  pennsylvanica   Green Ash
# 26         27    10776  DECIDUOUS  Fraxinus      americana   White Ash
# ..        ...      ...        ...       ...            ...         ...
# 704       705    10784  DECIDUOUS  Fraxinus      americana   White Ash
# 705       706    10800  DECIDUOUS  Fraxinus      americana   White Ash
# 706       707    10834  DECIDUOUS  Fraxinus  pennsylvanica   Green Ash
# 716       717    11623  DECIDUOUS  Fraxinus  pennsylvanica   Green Ash
# 717       718    11661  DECIDUOUS  Fraxinus      americana   White Ash
#
#      Canopy Spread  Height   Latitude   Longitude
# 22            15.0    30.0  40.009399 -105.274296
# 23            20.0    30.0  40.009773 -105.276228
# 24            20.0    30.0  40.009668 -105.276150
# 25            30.0    35.0  40.008355 -105.273982
# 26            15.0    30.0  40.010176 -105.274295
# ..             ...     ...        ...         ...
# 704           10.0    30.0  40.010043 -105.274232
# 705           15.0    35.0  40.010044 -105.273768
# 706           20.0    30.0  40.008964 -105.275708
# 716           40.0    51.0  40.009350 -105.274821
# 717           35.0    52.0  40.009693 -105.275857
#
# [97 rows x 10 columns]

# %%
# Replacing the calculated median height for Fraxinus

df.loc[(df['Genus'] == 'Fraxinus') & (df['Height'] == 0), 'Height'] = fraxinus_median

# %%
df.shape
# Out:
# (777, 10)

# %%
# Replacing the calculated median height for Crataegus

df.loc[(df['Genus'] == 'Crataegus') & (df['Height']== 0), 'Height'] = crataegus_median

# %%
# Checking again for outliers

df[df['Height'] == 0]
# Out:
#      OBJECTID  Tree ID  Tree Type      Genus       Species        Common Name  \
# 213       214    14138  DECIDUOUS  Hydrangea    paniculata  Panicle hydrangea
# 476       477    13797  DECIDUOUS      Pinus       Unknown               Pine
# 478       479    13804  DECIDUOUS      Malus       Unknown              Apple
# 767       768    13803  DECIDUOUS     Celtis  occidentalis   Common Hackberry
# 768       769    13812  DECIDUOUS    Rhamnus       Unknown          Buckthorn
#
#      Canopy Spread  Height   Latitude   Longitude
# 213            6.0     0.0  40.010040 -105.275953
# 476           12.0     0.0  40.009890 -105.273232
# 478           12.0     0.0  40.010040 -105.273185
# 767           12.0     0.0  40.010022 -105.273259
# 768           12.0     0.0  40.009924 -105.273231

# %%
# Since there are only 5 rows and it is very difficult determine the heights,because each Genus have many Spicies.
# Hence dropping those 5 rows (<1% of data)

df = df[df['Height'] > 0]

# %%
# completely cleaned data frame free from outliers, missing_values, duplicates

df
# Out:
#      OBJECTID  Tree ID  Tree Type        Genus    Species  \
# 0           1    10146  DECIDUOUS      Quercus    bicolor
# 1           2    10150  DECIDUOUS  Gymnocladus    dioicus
# 2           3    10041  DECIDUOUS      Quercus      rubra
# 3           4    10042  DECIDUOUS      Quercus      rubra
# 4           5    10051  DECIDUOUS    Crataegus    Unknown
# ..        ...      ...        ...          ...        ...
# 772       773    13830  DECIDUOUS     Taxodium    Unknown
# 773       774    13833  DECIDUOUS    Crataegus    Unknown
# 774       775    14027  DECIDUOUS      Catalpa   speciosa
# 775       776    15693  DECIDUOUS         Acer  saccharum
# 776       777    15694  DECIDUOUS         Acer  saccharum
#
#              Common Name  Canopy Spread  Height   Latitude   Longitude
# 0        Swamp White Oak           19.0    21.0  40.009104 -105.272529
# 1    Kentucky Coffeetree           31.0    47.0  40.009136 -105.272797
# 2       Northern Red Oak           65.0   102.0  40.008888 -105.274886
# 3       Northern Red Oak           42.0    54.0  40.008775 -105.275000
# 4              Hawthorne           18.0    20.0  40.008870 -105.275428
# ..                   ...            ...     ...        ...         ...
# 772         Bald Cypress           15.0    25.0  40.010252 -105.273964
# 773            Hawthorne           15.0    20.0  40.010316 -105.274258
# 774      Western Catalpa            5.0    10.0  40.008315 -105.272798
# 775                  NaN           18.0    30.0  40.009700 -105.274889
# 776          Sugar Maple           18.0    12.0  40.009862 -105.275143
#
# [772 rows x 10 columns]

# %%
# checking the stats for the final time

df.describe()
# Out:
#          OBJECTID       Tree ID  Canopy Spread      Height    Latitude  \
# count  772.000000    772.000000     772.000000  772.000000  772.000000
# mean   388.012953  12097.945596      19.393782   35.292098   40.009191
# std    224.203811   1305.734416      10.934203   18.431522    0.000820
# min      1.000000  10013.000000       3.000000    4.000000   40.007060
# 25%    193.750000  10757.750000      12.000000   20.000000   40.008573
# 50%    387.500000  12544.500000      16.000000   35.000000   40.009271
# 75%    582.250000  12984.250000      25.000000   47.250000   40.009939
# max    777.000000  15694.000000      65.000000  102.000000   40.010393
#
#         Longitude
# count  772.000000
# mean  -105.273815
# std      0.001290
# min   -105.276503
# 25%   -105.274791
# 50%   -105.273961
# 75%   -105.272860
# max   -105.270165

# %% [markdown]
# # EXPORTING THE CLEANED DATA FRAME

# %%
df.to_csv('cleaned_tree_2.csv')

# %%
# CHECKING FOR VERY TALL TREES.

df[df['Height'] > 90]
# Out:
#      OBJECTID  Tree ID  Tree Type    Genus      Species       Common Name  \
# 2           3    10041  DECIDUOUS  Quercus        rubra  Northern Red Oak
# 106       107    10140  DECIDUOUS     Acer  saccharinum      Silver Maple
# 369       370    10152  DECIDUOUS    Ulmus    americana      American Elm
# 600       601    10139  DECIDUOUS     Acer  saccharinum      Silver Maple
#
#      Canopy Spread  Height   Latitude   Longitude
# 2             65.0   102.0  40.008888 -105.274886
# 106           40.0    92.0  40.009072 -105.272593
# 369           60.0    93.0  40.009090 -105.272989
# 600           40.0    93.0  40.009046 -105.272452

# %% [markdown]
# ### Further analysis is done one Tableau by creating calculated fields and generating visualizations.
